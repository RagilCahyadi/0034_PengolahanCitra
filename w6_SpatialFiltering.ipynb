# %% [markdown]
# ### Maximum Spatial Filtering
# Digunakan untuk menambahi titik terang
#
# ### Minimum Spatial Filtering
# Digunakan untuk menambahi titik gelap
#
# ### Rumus Spatial Filtering

# %% [markdown]
# ### Weighted Smoothing Filter
# Piksel yang
#
# ### Strategy Edge Handling
# 1. Zero Padding
# Kelemahan nya ketika digunakan di grayscale karena akan menyebabkan gambar semakin gelap karena nilai neighbourhood nya 0
#
# 2. Replicate Edge Pixel
#
#
# 3. Wrap around the pixel

# %%
import cv2
